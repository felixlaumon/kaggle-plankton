# %%
from __future__ import print_function
from __future__ import division

import numpy as np
import pandas as pd
import theano

import data
import lasangeutils
import utils

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.preprocessing import LabelEncoder
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix

from lasagne import layers
from lasagne.updates import nesterov_momentum, rmsprop, adadelta
from lasagne.nonlinearities import softmax
from nolearn.lasagne import NeuralNet
from nolearn.lasagne import negative_log_likelihood
# Out:
# Using gpu device 0: GeForce GTX 670

# %%
# reload(data)
# reload(lasangeutils)
# reload(utils)

# %%
# %time X_orig, y_orig = data.load_data(random_n=5000, resize_shape=(48, 48), scale=True)

enc = LabelEncoder()
y = enc.fit_transform(y_orig)
# Out:
# Finished reading directories; found 30336 images
# Truncating data to 5000 row
# Scaling image output
# Resizing all images to (48, 48)
# CPU times: user 6.76 s, sys: 438 ms, total: 7.2 s
# Wall time: 7.21 s

# %% [markdown]
# ## Data Exploration

# %%
utils.plot_samples(X, y)

# %%
n_class = len(enc.classes_)
classes = enc.classes_
plt.figure(figsize=(20,20))
plt.hist(y, bins=len(set(y)))
plt.xticks(range(n_class), classes, rotation=90)
;
# Out:
# ''

# %% [markdown]
# ## Convnet

# %%
hw = 96
# %time X_orig, y_orig = data.load_data(resize_shape=(hw, hw), scale=True)

enc = LabelEncoder()
X = X_orig.astype(np.float32)
y = enc.fit_transform(y_orig).astype(np.int32)

X_train, X_test, y_train, y_test = train_test_split(X.reshape(-1, hw * hw), y, test_size=0.05, random_state=42)
X_train, X_test = X_train.reshape(-1, 1, hw, hw), X_test.reshape(-1, 1, hw, hw) # because train_test_split requires array to X

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# Finished reading directories; found 30336 images
# Scaling image output
# Resizing all images to (96, 96)
# CPU times: user 25.1 s, sys: 1.48 s, total: 26.6 s
# Wall time: 26.7 s
# (28819, 1, 96, 96)
#  (28819,) (1517, 1, 96, 96) (1517,)

# %%
net = NeuralNet(
    eval_size=0.1,

    layers=[
        ('input', layers.InputLayer),

        ('conv1', layers.Conv2DCCLayer),
        ('pool1', layers.MaxPool2DCCLayer),
        ('dropout1', layers.DropoutLayer),

        ('conv2', layers.Conv2DCCLayer),
        ('pool2', layers.MaxPool2DCCLayer),
        ('dropout2', layers.DropoutLayer),

        ('conv3', layers.Conv2DCCLayer),
#         ('pool3', layers.MaxPool2DCCLayer),
        ('dropout3', layers.DropoutLayer),

        ('hidden4', layers.DenseLayer),
        ('dropout4', layers.DropoutLayer),

        ('hidden5', layers.DenseLayer),

        ('output', layers.DenseLayer),
    ],

    input_shape=(None, 1, hw, hw),

    conv1_num_filters=96, conv1_filter_size=(3, 3),
    pool1_ds=(2, 2),
    dropout1_p=0.5,

    conv2_num_filters=128, conv2_filter_size=(3, 3),
    pool2_ds=(2, 2),
    dropout2_p=0.5,

    conv3_num_filters=128, conv3_filter_size=(3, 3),
    dropout3_p=0.5,

    # TODO try fully connected layer
    hidden4_num_units=512,
    dropout4_p=0.5,

    hidden5_num_units=512,

    output_num_units=len(set(y)),

    loss=negative_log_likelihood,

    batch_iterator_train=lasangeutils.MyBatchIterator(batch_size=128),
    batch_iterator_test=lasangeutils.MyBatchIterator(batch_size=128),

    update=nesterov_momentum,
    update_learning_rate=theano.shared(lasangeutils.float32(0.01)),
    update_momentum=theano.shared(lasangeutils.float32(0.9)),

#     update=rmsprop,
#     update=adadelta,

    regression=False,
    output_nonlinearity=softmax,

    on_epoch_finished=[
        lasangeutils.AdjustVariable('update_learning_rate', start=0.01, stop=0.001),
        lasangeutils.AdjustVariable('update_momentum', start=0.9, stop=0.999),
        lasangeutils.EarlyStopping(patience=50)
    ],

    max_epochs=1000,
    verbose=1
)

# %time net.fit(X_train, y_train)
ascore = net.score(X_test, y_test) 
print(ascore)
# Out:
# /home/felixlau/devel/Lasagne/src/theano/theano/sandbox/rng_mrg.py:1188: UserWarning: MRG_RandomStreams Can't determine #streams from size (Shape.0), guessing 60*256
#   nstreams = self.n_streams(size)
# /home/felixlau/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:413: Warning: The least populated class in y has only 8 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=10.
#   % (min_labels, self.n_folds)), Warning)
#   InputLayer        	(None, 1, 96, 96)   	produces    9216 outputs
#   Conv2DCCLayer     	(None, 96, 94, 94)  	produces  848256 outputs
#   MaxPool2DCCLayer  	(None, 96, 47, 47)  	produces  212064 outputs
#   DropoutLayer      	(None, 96, 47, 47)  	produces  212064 outputs
#   Conv2DCCLayer     	(None, 128, 45, 45) 	produces  259200 outputs
#   MaxPool2DCCLayer  	(None, 128, 23, 23) 	produces   67712 outputs
#   DropoutLayer      	(None, 128, 23, 23) 	produces   67712 outputs
#   Conv2DCCLayer     	(None, 128, 21, 21) 	produces   56448 outputs
#   DropoutLayer      	(None, 128, 21, 21) 	produces   56448 outputs
#   DenseLayer        	(None, 512)         	produces     512 outputs
#   DropoutLayer      	(None, 512)         	produces     512 outputs
#   DenseLayer        	(None, 512)         	produces     512 outputs
#   DenseLayer        	(None, 121)         	produces     121 outputs
#
#  Epoch  |  Train loss  |  Valid loss  |  Train / Val  |  Valid acc  |  Dur
# --------|--------------|--------------|---------------|-------------|-------
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-3-7b47b81ae100> in <module>()
#      71 )
#      72
# ---> 73 get_ipython().magic(u'time net.fit(X_train, y_train)')
#      74 ascore = net.score(X_test, y_test)
#      75 print(ascore)
#
# /home/felixlau/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2203         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2204         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2205         return self.run_line_magic(magic_name, magic_arg_s)
#    2206
#    2207     #-------------------------------------------------------------------------
#
# /home/felixlau/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2124                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2125             with self.builtin_trap:
# -> 2126                 result = fn(*args,**kwargs)
#    2127             return result
#    2128
#
# /home/felixlau/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#
# /home/felixlau/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /home/felixlau/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1123         if mode=='eval':
#    1124             st = clock2()
# -> 1125             out = eval(code, glob, local_ns)
#    1126             end = clock2()
#    1127         else:
#
# <timed eval> in <module>()
#
# /home/felixlau/anaconda/lib/python2.7/site-packages/nolearn-0.5b2dev-py2.7.egg/nolearn/lasagne.pyc in fit(self, X, y)
#     148
#     149         try:
# --> 150             self.train_loop(X, y)
#     151         except KeyboardInterrupt:
#     152             pdb.set_trace()
#
# /home/felixlau/anaconda/lib/python2.7/site-packages/nolearn-0.5b2dev-py2.7.egg/nolearn/lasagne.pyc in train_loop(self, X, y)
#     186
#     187             for Xb, yb in self.batch_iterator_train(X_train, y_train):
# --> 188                 batch_train_loss = self.train_iter_(Xb, yb)
#     189                 train_losses.append(batch_train_loss)
#     190
#
# /home/felixlau/devel/Lasagne/src/theano/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     596                     gof.link.raise_with_op(
#     597                         self.fn.nodes[self.fn.position_of_error],
# --> 598                         self.fn.thunks[self.fn.position_of_error])
#     599                 else:
#     600                     # For the c linker We don't have access from
#
# /home/felixlau/devel/Lasagne/src/theano/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     586         t0_fn = time.time()
#     587         try:
# --> 588             outputs = self.fn()
#     589         except Exception:
#     590             if hasattr(self.fn, 'position_of_error'):
#
# MemoryError: Error allocating 28901376 bytes of device memory (out of memory).
# Apply node that caused the error: GPU_mrg_uniform{CudaNdarrayType(float32, 4D),inplace}(<CudaNdarrayType(float32, vector)>, Elemwise{Cast{int32}}.0)
# Inputs types: [CudaNdarrayType(float32, vector), TensorType(int32, vector)]
# Inputs shapes: [(92160,), (4,)]
# Inputs strides: [(1,), (4,)]
# Inputs scalar values: ['not scalar', 'not scalar']
#
# HINT: Re-running with most Theano optimization disabled could give you a back-traces when this node was created. This can be done with by setting the Theano flags optimizer=fast_compile
# HINT: Use the Theano flag 'exception_verbosity=high' for a debugprint of this apply node.

# %%
utils.plot_loss(net)

# %%
y_pred = net.predict(X_test)
y_pred_proba = net.predict_proba(X_test)
lscore = utils.multiclass_log_loss(y_test, y_pred_proba)
ascore = net.score(X_test, y_test)
print('multiclass log loss', lscore)
print('accuracy', ascore)
# Out:
# multiclass log loss 1.92392277463
# accuracy 0.530652603823

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=False,  fmt='');

# %%
utils.save(net, 'net-%s' % lscore)

# %%
correct_indies = np.where(y_pred == y_test)
X_test_correct = X_test[correct_indies]
y_pred_correct = y_pred[correct_indies]
y_test_actual = y_test[correct_indies]
utils.plot_samples(X_test_correct, y_pred_correct, y_pred=y_test_actual)

# %%
wrong_indies = np.where(y_pred != y_test)
X_test_wrong = X_test[wrong_indies]
y_pred_wrong = y_pred[wrong_indies]
y_test_actual = y_test[wrong_indies]
utils.plot_samples(X_test_wrong, y_pred_wrong, y_pred=y_test_actual)
