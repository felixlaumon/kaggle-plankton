# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ..
# Out:
# /home/felixlau/devel/plankton

# %%
from __future__ import print_function, division

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from plankton import utils

# %%
# %time X, y = np.load('data/X_train_48.npy'), np.load('data/y_train_48.npy')
# Out:
# CPU times: user 3.96 ms, sys: 48.4 ms, total: 52.4 ms
# Wall time: 51.8 ms

# %%
enc = utils.load_from_pickle('data/y_train_encoder-2015-02-21-18-41-54.pickle')

# %%
utils.plot_samples(X, enc.inverse_transform(y))

# %%
n_class = len(enc.classes_)
classes = enc.classes_
plt.figure(figsize=(20,8))
plt.hist(y, bins=len(set(y)))
plt.xticks(range(n_class), classes, rotation=90);

# %%
len(set(y))
# Out:
# 121
