# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ..
# Out:
# /home/felixlau/devel/plankton

# %%
from __future__ import print_function, division

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from plankton import utils

# %%
# %time X, y, y_superclass = np.load('data/X_train_48.npy'), np.load('data/y_train_48.npy'), np.load('data/y_train_superclass_48.npy')
# Out:
# CPU times: user 4.48 ms, sys: 52.7 ms, total: 57.1 ms
# Wall time: 56.6 ms

# %%
y_enc = utils.load_from_pickle('data/y_train_encoder-2015-03-03-20-55-48.pickle')
y_superclass_enc = utils.load_from_pickle('data/y_train_superclass_encoder-2015-03-03-20-55-48.pickle')

# %%
utils.plot_samples(X, y_enc.inverse_transform(y))

# %%
n_class = len(y_enc.classes_)
classes = y_enc.classes_
plt.figure(figsize=(20,8))
plt.hist(y, bins=len(set(y)))
plt.xticks(range(n_class), classes, rotation=90);

# %%
n_class = len(y_superclass_enc.classes_)
classes = y_superclass_enc.classes_
plt.figure(figsize=(20,8))
plt.hist(y_superclass, bins=len(set(y_superclass)))
plt.xticks(range(n_class), classes, rotation=90);

# %%
len(set(y))
# Out:
# 121

# %%
len(set(y_superclass))
# Out:
# 35
