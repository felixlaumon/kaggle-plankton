# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ..
# Out:
# /home/felixlau/devel/plankton

# %%
from __future__ import print_function, division

import numpy as np
import pandas as pd
import theano

from plankton import utils

import matplotlib.pyplot as plt
import matplotlib.gridspec
import seaborn as sns
# %matplotlib inline
# Out:
# Using gpu device 0: GeForce GTX 670

# %%
X, y = np.load('data/X_train_48.npy'), np.load('data/y_train_48.npy')
y_enc = utils.load_from_pickle('data/y_train_encoder-2015-02-21-21-04-01.pickle')
indices = np.random.choice(len(X), 500)
Xhat = X[indices]
yhat = y[indices]

# %%
# net = utils.load_from_pickle('models/net-2.52293672634-2015-02-21-19-11-11.pickle')
# net = utils.load_from_pickle('models/net-net_mar3_specialist_1-0.623163549407-2015-03-04-14-35-06.pickle')
net = utils.load_from_pickle('models/net-net_mar3_specialist_1-0.682265660406-2015-03-05-06-26-17.pickle')
net_layers = net.get_all_layers()
# Out:
#   InputLayer        	(None, 1, 48, 48)   	produces    2304 outputs
#   Conv2DDNNLayer    	(None, 128, 46, 46) 	produces  270848 outputs
#   MaxPool2DDNNLayer 	(None, 128, 23, 23) 	produces   67712 outputs
#   DropoutLayer      	(None, 128, 23, 23) 	produces   67712 outputs
#   Conv2DDNNLayer    	(None, 256, 21, 21) 	produces  112896 outputs
#   MaxPool2DDNNLayer 	(None, 256, 10, 10) 	produces   25600 outputs
#   DropoutLayer      	(None, 256, 10, 10) 	produces   25600 outputs
#   Conv2DDNNLayer    	(None, 512, 8, 8)   	produces   32768 outputs
#   MaxPool2DDNNLayer 	(None, 512, 4, 4)   	produces    8192 outputs
#   DropoutLayer      	(None, 512, 4, 4)   	produces    8192 outputs
#   DenseLayer        	(None, 2048)        	produces    2048 outputs
#   FeaturePoolLayer  	(None, 1024)        	produces    1024 outputs
#   DropoutLayer      	(None, 1024)        	produces    1024 outputs
#   DenseLayer        	(None, 2048)        	produces    2048 outputs
#   FeaturePoolLayer  	(None, 1024)        	produces    1024 outputs
#   DropoutLayer      	(None, 1024)        	produces    1024 outputs
#   DenseLayer        	(None, 2048)        	produces    2048 outputs
#   FeaturePoolLayer  	(None, 1024)        	produces    1024 outputs
#   DropoutLayer      	(None, 1024)        	produces    1024 outputs
#   DenseLayer        	(None, 121)         	produces     121 outputs

# %% [markdown]
# ### Any dead neurons at conv layers?

# %%
for layer in net_layers:
    layer_name = layer.__class__.__name__
    if 'Conv' in layer_name:
        plt.figure()
        utils.vis_layer_weights(layer)

# %% [markdown]
# ### Sanity check dense layer by t-sne

# %%
for layer in net_layers:
    layer_name = layer.__class__.__name__
    if 'Dense' in layer_name:
        plt.figure()
        utils.plot_tsne(layer, Xhat, yhat)

# %% [markdown]
# ## Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
y_pred = net.predict(X)

# %%
cm = confusion_matrix(y, y_pred)

# %%
print(classification_report(y, y_pred, target_names=y_enc.classes_))
# Out:
#                                                precision    recall  f1-score   support
#
#                            acantharia_protist       0.98      0.98      0.98       889
#                 acantharia_protist_big_center       1.00      0.62      0.76        13
#                       acantharia_protist_halo       0.84      0.97      0.90        71
#                                     amphipods       0.89      0.80      0.84        49
#                 appendicularian_fritillaridae       1.00      0.25      0.40        16
#                       appendicularian_s_shape       0.95      0.97      0.96       696
#                  appendicularian_slight_curve       0.91      0.96      0.93       532
#                      appendicularian_straight       0.97      0.93      0.95       242
#                                     artifacts       0.98      0.99      0.99       393
#                                artifacts_edge       0.98      0.99      0.99       170
#                       chaetognath_non_sagitta       0.87      0.83      0.85       815
#                             chaetognath_other       0.88      0.91      0.90      1934
#                           chaetognath_sagitta       0.85      0.83      0.84       694
#                                chordate_type1       0.97      0.95      0.96        77
#                              copepod_calanoid       0.91      0.88      0.89       681
#                         copepod_calanoid_eggs       0.94      0.97      0.96       173
#                    copepod_calanoid_eucalanus       0.99      0.99      0.99        96
#                    copepod_calanoid_flatheads       0.73      0.88      0.80       178
#               copepod_calanoid_frillyAntennae       0.98      0.75      0.85        63
#                        copepod_calanoid_large       0.92      0.89      0.91       286
#     copepod_calanoid_large_side_antennatucked       0.83      0.95      0.89       106
#                     copepod_calanoid_octomoms       0.96      0.88      0.91        49
#           copepod_calanoid_small_longantennae       0.89      0.99      0.93        87
#                     copepod_cyclopoid_copilia       0.91      0.97      0.94        30
#                     copepod_cyclopoid_oithona       0.96      0.98      0.97       899
#                copepod_cyclopoid_oithona_eggs       0.99      0.98      0.99      1189
#                                 copepod_other       1.00      0.12      0.22        24
#                              crustacean_other       0.81      0.89      0.85       201
#                             ctenophore_cestid       0.99      0.99      0.99       113
#              ctenophore_cydippid_no_tentacles       0.93      0.93      0.93        42
#                 ctenophore_cydippid_tentacles       0.95      0.75      0.84        53
#                             ctenophore_lobate       0.93      0.97      0.95        38
#                                      decapods       0.89      0.91      0.90        55
#                                 detritus_blob       0.84      0.73      0.78       363
#                          detritus_filamentous       0.91      0.84      0.87       394
#                                detritus_other       0.88      0.93      0.90       914
#                           diatom_chain_string       0.92      0.97      0.94       519
#                             diatom_chain_tube       0.86      0.93      0.89       500
#          echinoderm_larva_pluteus_brittlestar       0.94      0.86      0.90        36
#                echinoderm_larva_pluteus_early       0.92      0.93      0.93        92
#                echinoderm_larva_pluteus_typeC       0.89      0.99      0.93        80
#               echinoderm_larva_pluteus_urchin       0.95      0.90      0.92        88
#           echinoderm_larva_seastar_bipinnaria       0.95      0.95      0.95       385
#         echinoderm_larva_seastar_brachiolaria       0.97      0.97      0.97       536
#      echinoderm_seacucumber_auricularia_larva       0.96      0.97      0.96        96
#                                 echinopluteus       1.00      0.93      0.96        27
#                                        ephyra       1.00      0.93      0.96        14
#                                   euphausiids       0.92      0.92      0.92       136
#                             euphausiids_young       0.70      0.79      0.74        38
#                                  fecal_pellet       0.91      0.81      0.86       511
#                         fish_larvae_deep_body       1.00      0.50      0.67        10
#                      fish_larvae_leptocephali       0.91      0.97      0.94        31
#                       fish_larvae_medium_body       0.90      0.93      0.91        85
#                        fish_larvae_myctophids       0.93      0.99      0.96       114
#                         fish_larvae_thin_body       0.88      0.81      0.85        64
#                    fish_larvae_very_thin_body       1.00      0.50      0.67        16
#                                     heteropod       1.00      0.40      0.57        10
#                          hydromedusae_aglaura       0.91      0.97      0.94       127
#               hydromedusae_bell_and_tentacles       0.86      0.84      0.85        75
#                              hydromedusae_h15       0.82      0.91      0.86        35
#                        hydromedusae_haliscera       0.97      1.00      0.98       229
#         hydromedusae_haliscera_small_sideview       1.00      0.67      0.80         9
#                          hydromedusae_liriope       0.93      0.68      0.79        19
#                       hydromedusae_narco_dark       1.00      0.83      0.90        23
#                      hydromedusae_narco_young       0.93      0.96      0.95       336
#                     hydromedusae_narcomedusae       0.96      0.83      0.89       132
#                            hydromedusae_other       1.00      0.08      0.15        12
#                     hydromedusae_partial_dark       0.98      0.95      0.96       190
#                           hydromedusae_shapeA       0.98      0.98      0.98       412
#            hydromedusae_shapeA_sideview_small       0.90      0.91      0.90       274
#                           hydromedusae_shapeB       0.85      0.88      0.87       150
#                     hydromedusae_sideview_big       0.91      0.80      0.85        76
#                         hydromedusae_solmaris       0.96      0.97      0.97       703
#                      hydromedusae_solmundella       1.00      0.97      0.98       123
#                            hydromedusae_typeD       0.89      0.91      0.90        43
#         hydromedusae_typeD_bell_and_tentacles       0.87      0.96      0.92        56
#                            hydromedusae_typeE       1.00      0.93      0.96        14
#                            hydromedusae_typeF       0.95      0.95      0.95        61
#                   invertebrate_larvae_other_A       1.00      0.79      0.88        14
#                   invertebrate_larvae_other_B       0.92      0.92      0.92        24
#                             jellies_tentacles       0.96      0.96      0.96       141
#                                    polychaete       0.98      0.99      0.98       131
#                           protist_dark_center       0.86      0.85      0.86       108
#                           protist_fuzzy_olive       0.87      0.97      0.91       372
#                             protist_noctiluca       0.82      0.87      0.84       625
#                                 protist_other       0.91      0.84      0.87      1172
#                                  protist_star       0.91      0.93      0.92       113
#                            pteropod_butterfly       0.90      0.98      0.94       108
#                        pteropod_theco_dev_seq       1.00      0.62      0.76        13
#                             pteropod_triangle       0.95      0.95      0.95        65
#                             radiolarian_chain       0.94      0.97      0.95       287
#                            radiolarian_colony       0.97      0.88      0.92       158
#                             shrimp-like_other       0.73      0.46      0.56        52
#                               shrimp_caridean       0.87      0.82      0.84        49
#                            shrimp_sergestidae       0.97      1.00      0.99       153
#                                   shrimp_zoea       0.84      0.90      0.87       174
#            siphonophore_calycophoran_abylidae       0.94      0.98      0.96       212
#    siphonophore_calycophoran_rocketship_adult       0.90      0.95      0.92       135
#    siphonophore_calycophoran_rocketship_young       0.91      0.98      0.95       483
#       siphonophore_calycophoran_sphaeronectes       0.92      0.97      0.94       179
#  siphonophore_calycophoran_sphaeronectes_stem       0.98      0.79      0.87        57
# siphonophore_calycophoran_sphaeronectes_young       0.93      0.91      0.92       247
#                      siphonophore_other_parts       0.75      0.10      0.18        29
#                          siphonophore_partial       1.00      0.80      0.89        30
#                        siphonophore_physonect       0.90      0.96      0.93       128
#                  siphonophore_physonect_young       1.00      0.67      0.80        21
#                                    stomatopod       0.88      0.92      0.90        24
#                    tornaria_acorn_worm_larvae       0.97      0.97      0.97        38
#                          trichodesmium_bowtie       0.90      0.92      0.91       708
#                        trichodesmium_multiple       0.91      0.93      0.92        54
#                            trichodesmium_puff       0.98      0.97      0.98      1979
#                            trichodesmium_tuft       0.89      0.93      0.91       678
#                            trochophore_larvae       0.88      0.97      0.92        29
#                             tunicate_doliolid       0.93      0.94      0.94       439
#                       tunicate_doliolid_nurse       0.95      0.94      0.94       417
#                              tunicate_partial       0.96      0.99      0.98       352
#                                 tunicate_salp       0.94      0.94      0.94       236
#                          tunicate_salp_chains       0.91      0.95      0.93        73
#                     unknown_blobs_and_smudges       0.83      0.74      0.78       317
#                                unknown_sticks       0.84      0.71      0.77       175
#                          unknown_unclassified       0.88      0.78      0.83       425
#
#                                   avg / total       0.92      0.92      0.92     30336

# %% [markdown]
# ## Tree strucutre
#
# - http://www.cs.toronto.edu/~nitish/treebasedpriors.pdf

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
superclass = np.array(map(lambda str: str.split('_')[0], y_enc.classes_))

# %%
y_pred_superclass = map(lambda x: superclass[x], y_pred)

# %%
y_superclass = map(lambda x: superclass[x], y)

# %%
print(classification_report(y_superclass, y_pred_superclass))
# Out:
#              precision    recall  f1-score   support
#
#  acantharia       0.98      0.99      0.98       973
#   amphipods       0.89      0.80      0.84        49
# appendicularian       0.98      1.00      0.99      1486
#   artifacts       0.99      1.00      0.99       563
# chaetognath       0.99      0.99      0.99      3443
#    chordate       0.97      0.95      0.96        77
#     copepod       0.99      1.00      0.99      3861
#  crustacean       0.81      0.89      0.85       201
#  ctenophore       0.97      0.93      0.95       246
#    decapods       0.89      0.91      0.90        55
#    detritus       0.95      0.94      0.94      1671
#      diatom       0.92      0.98      0.95      1019
#  echinoderm       0.99      0.99      0.99      1313
# echinopluteus       1.00      0.93      0.96        27
#      ephyra       1.00      0.93      0.96        14
# euphausiids       0.93      0.95      0.94       174
#       fecal       0.91      0.81      0.86       511
#        fish       0.97      0.96      0.97       320
#   heteropod       1.00      0.40      0.57        10
# hydromedusae       0.99      0.99      0.99      3099
# invertebrate       0.94      0.87      0.90        38
#     jellies       0.96      0.96      0.96       141
#  polychaete       0.98      0.99      0.98       131
#     protist       0.98      0.98      0.98      2390
#    pteropod       0.95      0.97      0.96       186
# radiolarian       0.97      0.96      0.96       445
#      shrimp       0.93      0.97      0.95       376
# shrimp-like       0.73      0.46      0.56        52
# siphonophore       0.98      0.99      0.98      1521
#  stomatopod       0.88      0.92      0.90        24
#    tornaria       0.97      0.97      0.97        38
# trichodesmium       0.98      0.99      0.99      3419
# trochophore       0.88      0.97      0.92        29
#    tunicate       0.98      0.99      0.99      1517
#     unknown       0.89      0.78      0.83       917
#
# avg / total       0.97      0.97      0.97     30336

# %%
accuracy_score(y_superclass, y_pred_superclass)
# Out:
# 0.97385944092827004
