# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ..
# Out:
# /home/felixlau/devel/plankton

# %%
from __future__ import print_function, division

import numpy as np
import pandas as pd
import theano

from plankton import utils

import matplotlib.pyplot as plt
import matplotlib.gridspec
import seaborn as sns
# %matplotlib inline

# %%
net = utils.load_from_pickle('models/net-2.52293672634-2015-02-21-19-11-11.pickle')
net_layers = net.get_all_layers()
# Out:
# [autoreload of plankton.net_feb21_base failed: Traceback (most recent call last):
#   File "/home/felixlau/anaconda/lib/python2.7/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# ValueError: Unused kwarg: l23_ds
# ]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-ef45b2f10cbf> in <module>()
# ----> 1 net = utils.load_from_pickle('models/net-1.06099911104-2015-02-08-13-46-50.pickle')
#       2 net_layers = net.get_all_layers()
#
# /home/felixlau/devel/plankton/plankton/utils.pyc in load_from_pickle(filename)
#     117
#     118 def load_from_pickle(filename):
# --> 119     return pickle.load(open(filename, 'rb'))
#     120
#     121
#
# ImportError: No module named lasagneutils

# %%
for layer in net_layers:
    layer_name = layer.__class__.__name__
    if 'Conv' in layer_name:
        plt.figure()
        utils.vis_layer_weights(layer)

# %%
X, y = np.load('data/X_train_48.npy'), np.load('data/y_train_48.npy')
indices = np.random.choice(len(X), 500)
Xhat = X[indices]
yhat = y[indices]

# %%
for layer in net_layers:
    layer_name = layer.__class__.__name__
    if 'Conv' in layer_name or 'Dense' in layer_name:
        plt.figure()
        utils.plot_tsne(layer, Xhat, yhat)
